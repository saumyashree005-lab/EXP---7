# %% [markdown]
# EXPERIMENT 7 : TO STUDY LOOPS IN PYTHON (NAME- SAUMYA  PRN- 25070123161)

# %%
#Print i as long as i is less than 6
i = 1
while i < 6:
  print(i)
  i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#Print numbers from 1 to N
n = int(input("ENTER N: "))
i = 1
while i <=n:
  print(i)
  i+=1
# Out:
# ENTER N: 9
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
#Factorial of a number
n = int(input("ENTER N: "))
fact = 1
while n>0:
  fact = fact*n
  n-=1
print("FACTORIAL: ",fact)
# Out:
# ENTER N: 5
# FACTORIAL:  120

# %%
#Fabbonaci Series
n = int(input("Enter the number of terms: "))
a = 0
b = 1
i = 1
while i <= n:
    print(a, end=" ")
    c = a + b
    a = b
    b = c
    i += 1
# Out:
# Enter the number of terms: 5
# 0 1 1 2 3

# %%
# Fibbonaci series including a limit
limit = int(input("Enter limit: "))
a = 0
b = 1
while a<= limit:
  print(a, end=" ")
  a, b = b, a+b
# Out:
# Enter limit: 10
# 0 1 1 2 3 5 8

# %%
# Reverse a number:
n = int(input("Enter a number: "))
rev = 0
while n > 0:
    digit = n % 10
    rev = rev * 10 + digit
    n //= 10
print("Reversed number =",rev)
# Out:
# Enter a number: 1234
# Reversed number = 4321

# %%
#Check pallindrome number/string
num = int(input("Enter a number: "))
temp = num
rev = 0
while num > 0:
  rev = rev * 10 + num % 10
  num //= 10
  if temp == rev:
    print("Number is pallindrome")
  else:
    print("Number is not pallindrome")
# Out:
# Enter a number: 121
# Number is not pallindrome
# Number is not pallindrome
# Number is pallindrome

# %%
#Check pallindrome for MADAM
s = "madam"
i, j = 0, len(s) - 1
is_palindrome = True
while i < j:
    if s[i] != s[j]:
        is_palindrome = False
        break
    i += 1
    j -= 1
if is_palindrome:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
#Check pallindrome string
string = input("Enter a string: ")
rev = string[::-1]
if string == rev:
  print("String is pallindrome")
else:
  print("String is not pallindrome")
# Out:
# Enter a string: MOM
# String is pallindrome

# %%
#Count digits in a number
num = int(input("Enter a number:"))
count = 0
while num > 0:
  count += 1
  num = num//10
print("Number of digits =", count)
# Out:
# Enter a number:234
# Number of digits = 3

# %%
#Search an element in the list
nums = [10,20,30,40,50]
key = int(input("Enter element to search: "))

i = 0
while i < len(nums):
  if nums[i] == key:
    print("Element found at index:", i)
    break
  i += 1

else:
  print("Element not found")
# Out:
# Enter element to search: 20
# Element found at index: 1

# %%
#Print only odd numbers from (1-10)
i = 0
while i < 10:
  i += 1
  if i % 2 == 0:
    continue
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9
